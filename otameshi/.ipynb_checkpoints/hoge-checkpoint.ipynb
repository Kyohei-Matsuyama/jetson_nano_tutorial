# %%
print("hello")
# Out:
# hello

# %%
import sys

# %%
import bs4

# %%
import numpy

# %%
import torch

# %%
if torch.cuda.is_available():
    print("cuda")
else:
    print("No use GPU")
# Out:
# cuda

# %%
print(torch.zeros((2,3)))
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
import torchvision

# %%
torchvision.__version__
# Out:
# '0.11.1'
